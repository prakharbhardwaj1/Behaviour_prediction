# %% [markdown]
# #Boosting Monocular Depth Estimation Models to High-Resolution via Content-Adaptive Multi-Resolution Merging
#
# This Colab Notebook contains an inference on the implementation from https://github.com/compphoto/BoostingMonocularDepth.
#
# It supports using [MiDas-v2][1] and [LeRes][2] but not [SGRnet][3].
#
#
# ### Instructions
# 0. Ensure using a GPU by setting "Runtime/change runtime type" to GPU
# 1. Run code section 1
# 2. Put your test images inside /content/inputs. Allowed file formats: png, jpeg, and jpg. Other file formats are ignored by dataloader.
# 3. Run code section 2:  it will download the needed model weights for both [MiDas-v2][1] and [LeRes][2].
#
# 5. Run code section 3
# 4. Run code section "Ours with MiDas" or "Ours with LeRes" to generate the results
# 3. Results will be generated in /content/outputs_midas or /content/outputs_leres folders.
#
#
# [1]: https://github.com/intel-isl/MiDaS/tree/v2
# [2]: https://github.com/aim-uofa/AdelaiDepth/tree/main/LeReS
# [3]: https://github.com/KexianHust/Structure-Guided-Ranking-Loss

# %%
# Code section 1

# !mkdir -p inputs
# !mkdir -p outputs_midas
# !mkdir -p outputs_leres

# %%
# Code section 2


# Clone git repo
# !git clone https://github.com/compphoto/BoostingMonocularDepth.git

# !wget https://sfu.ca/~yagiz/CVPR21/latest_net_G.pth
#!gdown https://drive.google.com/u/0/uc?id=1cU2y-kMbt0Sf00Ns4CN2oO9qPJ8BensP&export=download

# Downloading merge model weights
# !mkdir -p /content/BoostingMonocularDepth/pix2pix/checkpoints/mergemodel/
# !mv latest_net_G.pth /content/BoostingMonocularDepth/pix2pix/checkpoints/mergemodel/

# Downloading Midas weights
# !wget https://github.com/AlexeyAB/MiDaS/releases/download/midas_dpt/midas_v21-f6b98070.pt
# !mv midas_v21-f6b98070.pt /content/BoostingMonocularDepth/midas/model.pt

# # Downloading LeRes weights
# !wget https://cloudstor.aarnet.edu.au/plus/s/lTIJF4vrvHCAI31/download
# !mv download /content/BoostingMonocularDepth/res101.pth
# !wget https://huggingface.co/lllyasviel/Annotators/resolve/850be791e8f704b2fa2e55ec9cc33a6ae3e28832/res101.pth
# !mv res101.pth /content/BoostingMonocularDepth/res101.pth
# Out:
# Cloning into 'BoostingMonocularDepth'...
# remote: Enumerating objects: 368, done.
# remote: Counting objects: 100% (368/368), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 368 (delta 160), reused 325 (delta 146), pack-reused 0 (from 0)
# Receiving objects: 100% (368/368), 55.53 MiB | 38.14 MiB/s, done.
# Resolving deltas: 100% (160/160), done.
# --2025-07-29 10:08:13--  https://sfu.ca/~yagiz/CVPR21/latest_net_G.pth
# Resolving sfu.ca (sfu.ca)... 142.58.226.71, 142.58.103.17, 142.58.103.137, ...
# Connecting to sfu.ca (sfu.ca)|142.58.226.71|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.sfu.ca/~yagiz/CVPR21/latest_net_G.pth [following]
# --2025-07-29 10:08:13--  https://www.sfu.ca/~yagiz/CVPR21/latest_net_G.pth
# Resolving www.sfu.ca (www.sfu.ca)... 142.58.226.71
# Connecting to www.sfu.ca (www.sfu.ca)|142.58.226.71|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 318268048 (304M)
# Saving to: ‘latest_net_G.pth’
#
# latest_net_G.pth    100%[===================>] 303.52M  14.4MB/s    in 21s
#
# 2025-07-29 10:08:34 (14.3 MB/s) - ‘latest_net_G.pth’ saved [318268048/318268048]
#
# --2025-07-29 10:08:35--  https://github.com/AlexeyAB/MiDaS/releases/download/midas_dpt/midas_v21-f6b98070.pt
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/280183797/fbebca80-97de-11eb-8da9-8d9645bd6d6f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-29T10%3A53%3A32Z&rscd=attachment%3B+filename%3Dmidas_v21-f6b98070.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-29T09%3A52%3A53Z&ske=2025-07-29T10%3A53%3A32Z&sks=b&skv=2018-11-09&sig=BrFQnrBiabLQ%2FRosk8KjrFPDkL1sAxr3fMugf7El7jo%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mzc4NDAxNSwibmJmIjoxNzUzNzgzNzE1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1ESlGRtIb7WswXJkfN33OD_qM_pU6xnRyFNdbN8AS4Q&response-content-disposition=attachment%3B%20filename%3Dmidas_v21-f6b98070.pt&response-content-type=application%2Foctet-stream [following]
# --2025-07-29 10:08:35--  https://release-assets.githubusercontent.com/github-production-release-asset/280183797/fbebca80-97de-11eb-8da9-8d9645bd6d6f?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-29T10%3A53%3A32Z&rscd=attachment%3B+filename%3Dmidas_v21-f6b98070.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-29T09%3A52%3A53Z&ske=2025-07-29T10%3A53%3A32Z&sks=b&skv=2018-11-09&sig=BrFQnrBiabLQ%2FRosk8KjrFPDkL1sAxr3fMugf7El7jo%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1Mzc4NDAxNSwibmJmIjoxNzUzNzgzNzE1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1ESlGRtIb7WswXJkfN33OD_qM_pU6xnRyFNdbN8AS4Q&response-content-disposition=attachment%3B%20filename%3Dmidas_v21-f6b98070.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 422509849 (403M) [application/octet-stream]
# Saving to: ‘midas_v21-f6b98070.pt’
#
# midas_v21-f6b98070. 100%[===================>] 402.94M   102MB/s    in 4.0s
#
# 2025-07-29 10:08:39 (99.6 MB/s) - ‘midas_v21-f6b98070.pt’ saved [422509849/422509849]
#
# --2025-07-29 10:08:39--  https://huggingface.co/lllyasviel/Annotators/resolve/850be791e8f704b2fa2e55ec9cc33a6ae3e28832/res101.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.55, 18.164.174.17, 18.164.174.23, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.55|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.hf.co/repos/a2/11/a211ef997fa284ad67caa591ca931692f9a8a018910b18a04d9e6dff396f02e3/1d696b2ef3e8336b057d0c15bc82d2fecef821bfebe5ef9d7671a5ec5dde520b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27res101.pth%3B+filename%3D%22res101.pth%22%3B&Expires=1753787320&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=SRCaCvpe0FndjICLOLc9Z1UZasPG71K8kLZQ8O1GWqkpr9ZETJaG5IwcVCLCVff9RRVjmbwPmOiNLu75JcAX3X5RtBAYm75Fc0sVxYsA9gZhSC5Ull-h6mrP3DvgIXl25jNw48PcnAVm9AFe1VC9BpsZapi4MVLWFD038bFdOOVMQOf4o%7EynoH0NG1WGpNoEVcoJfo-uv0hTUj-0X5JZvTf0zNG78GlLhEHMzeu8eL9xefQN3nosVnLQ4XG4XnqBY9mi8bEcRmgyfHt0lNgBNx1b4gKAKzPJeNXSLb3SzGQYcyjv6fC%7EOr43KzmBNqFhCG6IpH1PTKRl16UAXahV7Q__&Key-Pair-Id=K3RPWS32NSSJCE [following]
# --2025-07-29 10:08:40--  https://cdn-lfs.hf.co/repos/a2/11/a211ef997fa284ad67caa591ca931692f9a8a018910b18a04d9e6dff396f02e3/1d696b2ef3e8336b057d0c15bc82d2fecef821bfebe5ef9d7671a5ec5dde520b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27res101.pth%3B+filename%3D%22res101.pth%22%3B&Expires=1753787320&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=SRCaCvpe0FndjICLOLc9Z1UZasPG71K8kLZQ8O1GWqkpr9ZETJaG5IwcVCLCVff9RRVjmbwPmOiNLu75JcAX3X5RtBAYm75Fc0sVxYsA9gZhSC5Ull-h6mrP3DvgIXl25jNw48PcnAVm9AFe1VC9BpsZapi4MVLWFD038bFdOOVMQOf4o%7EynoH0NG1WGpNoEVcoJfo-uv0hTUj-0X5JZvTf0zNG78GlLhEHMzeu8eL9xefQN3nosVnLQ4XG4XnqBY9mi8bEcRmgyfHt0lNgBNx1b4gKAKzPJeNXSLb3SzGQYcyjv6fC%7EOr43KzmBNqFhCG6IpH1PTKRl16UAXahV7Q__&Key-Pair-Id=K3RPWS32NSSJCE
# Resolving cdn-lfs.hf.co (cdn-lfs.hf.co)... 3.168.132.51, 3.168.132.48, 3.168.132.25, ...
# Connecting to cdn-lfs.hf.co (cdn-lfs.hf.co)|3.168.132.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 530760553 (506M) [binary/octet-stream]
# Saving to: ‘res101.pth’
#
# res101.pth          100%[===================>] 506.17M   291MB/s    in 1.7s
#
# 2025-07-29 10:08:41 (291 MB/s) - ‘res101.pth’ saved [530760553/530760553]

# %%
# Code section 3
# %cd BoostingMonocularDepth/
# Out:
# /content/BoostingMonocularDepth

# %% [markdown]
# > After execution of Code section 3 you can run the following code sections multiple times to generate results but **do not run the previous code sections**. If you did so by mistake use "Runtime/ Reset factory runtime" and then start from step 0.

# %%
# Running the method using MiDas
# !python run.py --Final --data_dir /content/inputs --output_dir  /content/outputs_midas/ --depthNet 0
# Out:
# device: cuda
# Namespace(data_dir='/content/inputs', output_dir='/content/outputs_midas/', savepatchs=0, savewholeest=0, output_resolution=1, net_receptive_field_size=None, pix2pixsize=1024, depthNet=0, colorize_results=False, R0=False, R20=False, Final=True, max_res=inf)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: /content/inputs               	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 0                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: /content/outputs_midas/       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# Loading weights:  midas/model.pt
# Downloading: "https://github.com/facebookresearch/WSL-Images/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://download.pytorch.org/models/ig_resnext101_32x8-c38310e5.pth" to /root/.cache/torch/hub/checkpoints/ig_resnext101_32x8-c38310e5.pth
# 100% 340M/340M [00:01<00:00, 328MB/s]
# start processing
# processing image 0 : frame2
# 	 wholeImage being processed in : 2880
#  	 	 DEBUG| GPU THRESHOLD REACHED 2880 ---> 1568
# Adjust factor is: 1.0
# Selecting patchs ...
# Target resolution:  (3236, 5760, 3)
# Dynamicly change merged-in resolution; scale: 0.3331273176761434
# 	 Resulted depthmap res will be : (1078, 1919)
# patchs to process: 75
# 	 processing patch 0 | [  0   0 831 831]
# 	 processing patch 1 | [ 96   0 831 831]
# 	 processing patch 2 | [192   0 831 831]
# 	 processing patch 3 | [288   0 831 831]
# 	 processing patch 4 | [384   0 831 831]
# 	 processing patch 5 | [576   0 831 831]
# 	 processing patch 6 | [959   0 831 831]
# 	 processing patch 7 | [1061    5  821  821]
# 	 processing patch 8 | [490  11 810 810]
# 	 processing patch 9 | [1215   64  704  704]
# 	 processing patch 10 | [  0   0 640 640]
# 	 processing patch 11 | [  0  96 640 640]
# 	 processing patch 12 | [ 96   0 640 640]
# 	 processing patch 13 | [192   0 640 640]
# 	 processing patch 14 | [288   0 640 640]
# 	 processing patch 15 | [384   0 640 640]
# 	 processing patch 16 | [480   0 640 640]
# 	 processing patch 17 | [576   0 640 640]
# 	 processing patch 18 | [672   0 640 640]
# 	 processing patch 19 | [768   0 640 640]
# 	 processing patch 20 | [863   0 640 640]
# 	 processing patch 21 | [959   0 640 640]
# 	 processing patch 22 | [1055    0  640  640]
# 	 processing patch 23 | [1151    0  640  640]
# 	 processing patch 24 | [1247    0  640  640]
# 	 processing patch 25 | [1407   64  512  512]
# 	 processing patch 26 | [1407  160  512  512]
# 	 processing patch 27 | [  0   0 448 448]
# 	 processing patch 28 | [  0  96 448 448]
# 	 processing patch 29 | [  0 192 448 448]
# 	 processing patch 30 | [ 96   0 448 448]
# 	 processing patch 31 | [192   0 448 448]
# 	 processing patch 32 | [288   0 448 448]
# 	 processing patch 33 | [384   0 448 448]
# 	 processing patch 34 | [480   0 448 448]
# 	 processing patch 35 | [576   0 448 448]
# 	 processing patch 36 | [576 576 448 448]
# 	 processing patch 37 | [672   0 448 448]
# 	 processing patch 38 | [768   0 448 448]
# 	 processing patch 39 | [863   0 448 448]
# 	 processing patch 40 | [959   0 448 448]
# 	 processing patch 41 | [1055    0  448  448]
# 	 processing patch 42 | [1151    0  448  448]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 43 | [1247    0  448  448]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 44 | [1343    0  448  448]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 45 | [1439    0  448  448]
# 	 processing patch 46 | [490 586 426 426]
# 	 processing patch 47 | [704 608 384 384]
# 	 processing patch 48 | [522 714 362 362]
# 	 processing patch 49 | [618 714 362 362]
# 	 processing patch 50 | [714 714 362 362]
# 	 processing patch 51 | [432 720 352 352]
# 	 processing patch 52 | [442 634 330 330]
# 	 processing patch 53 | [1599   64  320  320]
# 	 processing patch 54 | [1599  160  320  320]
# 	 processing patch 55 | [1599  256  320  320]
# 	 processing patch 56 | [  0   0 256 256]
# 	 processing patch 57 | [  0  96 256 256]
# 	 processing patch 58 | [  0 192 256 256]
# 	 processing patch 59 | [  0 288 256 256]
# 	 processing patch 60 | [  0 384 256 256]
# 	 processing patch 61 | [ 96   0 256 256]
# 	 processing patch 62 | [192   0 256 256]
# 	 processing patch 63 | [288   0 256 256]
# 	 processing patch 64 | [384   0 256 256]
# 	 processing patch 65 | [480   0 256 256]
# 	 processing patch 66 | [863   0 256 256]
# 	 processing patch 67 | [959   0 256 256]
# 	 processing patch 68 | [1055    0  256  256]
# 	 processing patch 69 | [1151    0  256  256]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 70 | [1247    0  256  256]
# 	 processing patch 71 | [1343    0  256  256]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 72 | [1439    0  256  256]
# /content/BoostingMonocularDepth/run.py:263: RankWarning: Polyfit may be poorly conditioned
#   p_coef = np.polyfit(mapped.reshape(-1), patch_whole_estimate_base.reshape(-1), deg=1)
# 	 processing patch 73 | [1535    0  256  256]
# 	 processing patch 74 | [1631    0  256  256]
# finished

# %%
# Running the method using LeRes
# !python run.py --Final --data_dir /content/inputs --output_dir  /content/outputs_leres/ --depthNet 2
# Out:
# device: cuda
# Namespace(data_dir='/content/inputs', output_dir='/content/outputs_leres/', savepatchs=0, savewholeest=0, output_resolution=1, net_receptive_field_size=None, pix2pixsize=1024, depthNet=2, colorize_results=False, R0=False, R20=False, Final=True, max_res=inf)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: /content/inputs               	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
#                  depthNet: 2                             	[default: None]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#             generatevideo: None
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 672
#          max_dataset_size: 10000
#                   max_res: inf
#                     model: pix2pix4depth
#                n_layers_D: 3
#                      name: void
#                       ndf: 64
#                      netD: basic
#                      netG: unet_1024
#  net_receptive_field_size: None
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                      norm: none
#                  num_test: 50
#               num_threads: 4
#                output_dir: /content/outputs_leres/       	[default: None]
#                 output_nc: 1
#         output_resolution: None
#                     phase: test
#               pix2pixsize: None
#                preprocess: resize_and_crop
#                 savecrops: None
#              savewholeest: None
#            serial_batches: False
#                    suffix:
#                   verbose: False
# ----------------- End -------------------
# initialize network with normal
# loading the model from ./pix2pix/checkpoints/mergemodel/latest_net_G.pth
# start processing
# processing image 0 : f_july23_02_57
# 	 wholeImage being processed in : 1568
# Adjust factor is: 1.3761467889908257
# Selecting patchs ...
# Target resolution:  (2432, 4316, 3)
# Dynamicly change merged-in resolution; scale: 0.5254934210526315
# 	 Resulted depthmap res will be : (1278, 2268)
# patchs to process: 36
# 	 processing patch 0 | [   6    6 1164 1164]
# 	 processing patch 1 | [ 183    6 1164 1164]
# 	 processing patch 2 | [ 359    6 1164 1164]
# 	 processing patch 3 | [ 536    6 1164 1164]
# 	 processing patch 4 | [ 713    6 1164 1164]
# 	 processing patch 5 | [ 889    6 1164 1164]
# 	 processing patch 6 | [1124   64 1049 1049]
# 	 processing patch 7 | [  76  252 1026 1026]
# 	 processing patch 8 | [ 252  252 1026 1026]
# 	 processing patch 9 | [ 429  252 1026 1026]
# 	 processing patch 10 | [ 605  252 1026 1026]
# 	 processing patch 11 | [ 782  252 1026 1026]
# 	 processing patch 12 | [ 958  252 1026 1026]
# 	 processing patch 13 | [356   3 818 818]
# 	 processing patch 14 | [533   3 818 818]
# 	 processing patch 15 | [709   3 818 818]
# 	 processing patch 16 | [886   3 818 818]
# 	 processing patch 17 | [1063    3  818  818]
# 	 processing patch 18 | [1239    3  818  818]
# 	 processing patch 19 | [1416    3  818  818]
# 	 processing patch 20 | [ 38 214 748 748]
# 	 processing patch 21 | [1485  249  679  679]
# 	 processing patch 22 | [119 472 586 586]
# 	 processing patch 23 | [1743  153  517  517]
# 	 processing patch 24 | [1743  330  517  517]
# 	 processing patch 25 | [  0   0 471 471]
# 	 processing patch 26 | [  0 177 471 471]
# 	 processing patch 27 | [  0 353 471 471]
# 	 processing patch 28 | [  0 530 471 471]
# 	 processing patch 29 | [530   0 471 471]
# 	 processing patch 30 | [706   0 471 471]
# 	 processing patch 31 | [883   0 471 471]
# 	 processing patch 32 | [1059    0  471  471]
# 	 processing patch 33 | [1413    0  471  471]
# 	 processing patch 34 | [1589    0  471  471]
# 	 processing patch 35 | [1766    0  471  471]
# processing image 1 : f_july23_11_37
# 	 wholeImage being processed in : 1792
#  	 	 DEBUG| GPU THRESHOLD REACHED 1792 ---> 1568
# Adjust factor is: 1.3773903917910448
# Selecting patchs ...
# Target resolution:  (2781, 4937, 3)
# Dynamicly change merged-in resolution; scale: 0.3887090974469615
# 	 Resulted depthmap res will be : (1081, 1919)
# patchs to process: 29
# 	 processing patch 0 | [ 711   58 1015 1015]
# 	 processing patch 1 | [ 842   58 1015 1015]
# 	 processing patch 2 | [788   5 861 861]
# 	 processing patch 3 | [919   5 861 861]
# 	 processing patch 4 | [1050    5  861  861]
# 	 processing patch 5 | [1050  135  861  861]
# 	 processing patch 6 | [726  73 725 725]
# 	 processing patch 7 | [735 212 707 707]
# 	 processing patch 8 | [638 116 639 639]
# 	 processing patch 9 | [917   2 605 605]
# 	 processing patch 10 | [1047    2  605  605]
# 	 processing patch 11 | [1178    2  605  605]
# 	 processing patch 12 | [1308    2  605  605]
# 	 processing patch 13 | [1308  133  605  605]
# 	 processing patch 14 | [1308  264  605  605]
# 	 processing patch 15 | [664 272 588 588]
# 	 processing patch 16 | [576 184 502 502]
# 	 processing patch 17 | [897 114 382 382]
# 	 processing patch 18 | [906 514 365 365]
# 	 processing patch 19 | [  0   0 348 348]
# 	 processing patch 20 | [784 131 348 348]
# 	 processing patch 21 | [1175    0  348  348]
# 	 processing patch 22 | [1306    0  348  348]
# 	 processing patch 23 | [1437    0  348  348]
# 	 processing patch 24 | [1567    0  348  348]
# 	 processing patch 25 | [1567  131  348  348]
# 	 processing patch 26 | [1567  261  348  348]
# 	 processing patch 27 | [1567  392  348  348]
# 	 processing patch 28 | [1567  522  348  348]
# processing image 2 : f_july23_3_05
# 	 wholeImage being processed in : 2464
#  	 	 DEBUG| GPU THRESHOLD REACHED 2464 ---> 1568
# Adjust factor is: 1.0637579359719034
# Selecting patchs ...
# Target resolution:  (2954, 5242, 3)
# Dynamicly change merged-in resolution; scale: 0.36594448205822616
# 	 Resulted depthmap res will be : (1081, 1918)
# patchs to process: 49
# 	 processing patch 0 | [   2    2 1062 1062]
# 	 processing patch 1 | [ 125    2 1062 1062]
# 	 processing patch 2 | [ 248    2 1062 1062]
# 	 processing patch 3 | [ 371    2 1062 1062]
# 	 processing patch 4 | [ 494    2 1062 1062]
# 	 processing patch 5 | [ 617    2 1062 1062]
# 	 processing patch 6 | [ 752   14 1037 1037]
# 	 processing patch 7 | [108 231 850 850]
# 	 processing patch 8 | [231 231 850 850]
# 	 processing patch 9 | [354 231 850 850]
# 	 processing patch 10 | [476 231 850 850]
# 	 processing patch 11 | [599 231 850 850]
# 	 processing patch 12 | [722 231 850 850]
# 	 processing patch 13 | [  3 126 813 813]
# 	 processing patch 14 | [126   3 813 813]
# 	 processing patch 15 | [249   3 813 813]
# 	 processing patch 16 | [372   3 813 813]
# 	 processing patch 17 | [495   3 813 813]
# 	 processing patch 18 | [618   3 813 813]
# 	 processing patch 19 | [741   3 813 813]
# 	 processing patch 20 | [864   3 813 813]
# 	 processing patch 21 | [987   3 813 813]
# 	 processing patch 22 | [1185   78  664  664]
# 	 processing patch 23 | [251   5 564 564]
# 	 processing patch 24 | [374   5 564 564]
# 	 processing patch 25 | [497   5 564 564]
# 	 processing patch 26 | [620   5 564 564]
# 	 processing patch 27 | [743   5 564 564]
# 	 processing patch 28 | [1111    5  564  564]
# 	 processing patch 29 | [1234    5  564  564]
# 	 processing patch 30 | [1364   11  552  552]
# 	 processing patch 31 | [1364  134  552  552]
# 	 processing patch 32 | [1124  263  539  539]
# 	 processing patch 33 | [ 67 313 440 440]
# 	 processing patch 34 | [1340  356  353  353]
# 	 processing patch 35 | [  0   0 328 328]
# 	 processing patch 36 | [  0 123 328 328]
# 	 processing patch 37 | [  0 246 328 328]
# 	 processing patch 38 | [  0 369 328 328]
# 	 processing patch 39 | [  0 492 328 328]
# 	 processing patch 40 | [123 246 328 328]
# 	 processing patch 41 | [123 492 328 328]
# 	 processing patch 42 | [492   0 328 328]
# 	 processing patch 43 | [615   0 328 328]
# 	 processing patch 44 | [738   0 328 328]
# 	 processing patch 45 | [1230    0  328  328]
# 	 processing patch 46 | [1353    0  328  328]
# 	 processing patch 47 | [1475    0  328  328]
# 	 processing patch 48 | [1475  369  328  328]
# processing image 3 : f_july24_02_55
# 	 wholeImage being processed in : 2912
#  	 	 DEBUG| GPU THRESHOLD REACHED 2912 ---> 1568
# Adjust factor is: 1.0
# Selecting patchs ...
# Target resolution:  (3275, 5824, 3)
# Dynamicly change merged-in resolution; scale: 0.32916030534351143
# 	 Resulted depthmap res will be : (1078, 1917)
# patchs to process: 52
# 	 processing patch 0 | [548 105 969 969]
# 	 processing patch 1 | [221   0 959 959]
# 	 processing patch 2 | [332   0 959 959]
# 	 processing patch 3 | [442   0 959 959]
# 	 processing patch 4 | [553   0 959 959]
# 	 processing patch 5 | [664   0 959 959]
# 	 processing patch 6 | [774   0 959 959]
# 	 processing patch 7 | [885   0 959 959]
# 	 processing patch 8 | [1032   37  885  885]
# 	 processing patch 9 | [179  68 822 822]
# 	 processing patch 10 | [111   0 737 737]
# 	 processing patch 11 | [221   0 737 737]
# 	 processing patch 12 | [332   0 737 737]
# 	 processing patch 13 | [442   0 737 737]
# 	 processing patch 14 | [553   0 737 737]
# 	 processing patch 15 | [664   0 737 737]
# 	 processing patch 16 | [774   0 737 737]
# 	 processing patch 17 | [885   0 737 737]
# 	 processing patch 18 | [995   0 737 737]
# 	 processing patch 19 | [1106    0  737  737]
# 	 processing patch 20 | [1253   37  664  664]
# 	 processing patch 21 | [1253  147  664  664]
# 	 processing patch 22 | [163 163 632 632]
# 	 processing patch 23 | [  0   0 516 516]
# 	 processing patch 24 | [221   0 516 516]
# 	 processing patch 25 | [442   0 516 516]
# 	 processing patch 26 | [553   0 516 516]
# 	 processing patch 27 | [664   0 516 516]
# 	 processing patch 28 | [774   0 516 516]
# 	 processing patch 29 | [885   0 516 516]
# 	 processing patch 30 | [995   0 516 516]
# 	 processing patch 31 | [1106    0  516  516]
# 	 processing patch 32 | [1217    0  516  516]
# 	 processing patch 33 | [1327    0  516  516]
# 	 processing patch 34 | [121 232 495 495]
# 	 processing patch 35 | [137 137 463 463]
# 	 processing patch 36 | [1475   37  442  442]
# 	 processing patch 37 | [1475  147  442  442]
# 	 processing patch 38 | [1475  258  442  442]
# 	 processing patch 39 | [  0   0 295 295]
# 	 processing patch 40 | [  0 111 295 295]
# 	 processing patch 41 | [  0 221 295 295]
# 	 processing patch 42 | [  0 332 295 295]
# 	 processing patch 43 | [  0 442 295 295]
# 	 processing patch 44 | [553   0 295 295]
# 	 processing patch 45 | [664   0 295 295]
# 	 processing patch 46 | [774   0 295 295]
# 	 processing patch 47 | [885   0 295 295]
# 	 processing patch 48 | [1217    0  295  295]
# 	 processing patch 49 | [1327    0  295  295]
# 	 processing patch 50 | [1438    0  295  295]
# 	 processing patch 51 | [1548    0  295  295]
# finished
